# %% [markdown]
# # Fine-tuning QLoRA — Professions de foi (Archelec)
#
# **Modèle :** `meta-llama/Llama-3.2-1B-Instruct`
# **GPU cible :** Tesla T4 (fp16, pas de bf16)
# **Objectif :** apprendre au modèle à générer des professions de foi crédibles à partir d'un prompt structuré.
#
# **Pipeline :**
# 1. Authentification HuggingFace
# 2. Chargement dataset + métadonnées
# 3. Construction des prompts
# 4. Nettoyage OCR
# 5. Formatage chat template
# 6. Chargement modèle (QLoRA 4-bit)
# 7. Entraînement
# 8. Inférence & comparaison

# %%
# 1. Suppression forcée des versions existantes incompatibles
# %pip uninstall -y torch torchvision torchaudio
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --no-cache-dir

# 2. Installation stricte de la version CUDA 11.8
# %pip install -r requirements.txt
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (28 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading https://download-r2.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/python/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /opt/python/lib/python3.13/site-packages (from torch) (82.0.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/python/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/python/lib/python3.13/site-packages (from torch) (2026.3.0)
# Collecting nvidia-cuda-nvrtc-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_nvrtc_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 113.6 MB/s  0:00:000:00:01
# Collecting nvidia-cuda-runtime-cu11==11.8.89 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_runtime_cu11-11.8.89-py3-none-manylinux1_x86_64.whl (875 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 202.4 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.8.87 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cuda_cupti_cu11-11.8.87-py3-none-manylinux1_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 115.7 MB/s  0:00:00
# Collecting nvidia-cudnn-cu11==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cudnn_cu11-9.1.0.70-py3-none-manylinux2014_x86_64.whl (663.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 102.4 MB/s  0:00:0600:0100:01
# Collecting nvidia-cublas-cu11==11.11.3.6 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux1_x86_64.whl (417.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 109.9 MB/s  0:00:03a 0:00:01
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 113.1 MB/s  0:00:01a 0:00:01
# Collecting nvidia-curand-cu11==10.3.0.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_curand_cu11-10.3.0.86-py3-none-manylinux1_x86_64.whl (58.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 113.9 MB/s  0:00:00eta 0:00:01
# Collecting nvidia-cusolver-cu11==11.4.1.48 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux1_x86_64.whl (128.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 95.5 MB/s  0:00:01ta 0:00:01
# Collecting nvidia-cusparse-cu11==11.7.5.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux1_x86_64.whl (204.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 112.2 MB/s  0:00:01a 0:00:01
# Collecting nvidia-nccl-cu11==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nccl_cu11-2.21.5-py3-none-manylinux2014_x86_64.whl (147.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 112.2 MB/s  0:00:01a 0:00:01
# Collecting nvidia-nvtx-cu11==11.8.86 (from torch)
#   Downloading https://download.pytorch.org/whl/cu118/nvidia_nvtx_cu11-11.8.86-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==3.3.1 (from torch)
#   Downloading https://download-r2.pytorch.org/whl/triton-3.3.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy in /opt/python/lib/python3.13/site-packages (from torchvision) (2.4.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/python/lib/python3.13/site-packages (from torchvision) (12.2.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/python/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/cu118/torch-2.7.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl (905.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.2/905.2 MB 100.0 MB/s  0:00:090:00:0100:01
# Downloading https://download-r2.pytorch.org/whl/triton-3.3.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 MB 84.2 MB/s  0:00:01m0:00:0100:01
# Downloading https://download-r2.pytorch.org/whl/cu118/torchvision-0.22.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 118.2 MB/s  0:00:00
# Downloading https://download-r2.pytorch.org/whl/cu118/torchaudio-2.7.1%2Bcu118-cp313-cp313-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 117.2 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 109.8 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 139.3 MB/s  0:00:00
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 128.6 MB/s  0:00:00
# Installing collected packages: mpmath, triton, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, torchaudio
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [torchaudio]9 [torchaudio]]-cu11]11]1]
# Successfully installed filelock-3.25.2 mpmath-1.3.0 networkx-3.6.1 nvidia-cublas-cu11-11.11.3.6 nvidia-cuda-cupti-cu11-11.8.87 nvidia-cuda-nvrtc-cu11-11.8.89 nvidia-cuda-runtime-cu11-11.8.89 nvidia-cudnn-cu11-9.1.0.70 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.3.0.86 nvidia-cusolver-cu11-11.4.1.48 nvidia-cusparse-cu11-11.7.5.86 nvidia-nccl-cu11-2.21.5 nvidia-nvtx-cu11-11.8.86 sympy-1.14.0 torch-2.7.1+cu118 torchaudio-2.7.1+cu118 torchvision-0.22.1+cu118 triton-3.3.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting dotenv (from -r requirements.txt (line 1))
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting huggingface_hub (from -r requirements.txt (line 2))
#   Downloading huggingface_hub-1.9.1-py3-none-any.whl.metadata (14 kB)
# Collecting transformers (from -r requirements.txt (line 3))
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting datasets (from -r requirements.txt (line 4))
#   Downloading datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Collecting peft (from -r requirements.txt (line 5))
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Collecting trl (from -r requirements.txt (line 6))
#   Downloading trl-1.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting accelerate (from -r requirements.txt (line 7))
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes (from -r requirements.txt (line 8))
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting ipywidgets (from -r requirements.txt (line 9))
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dotenv in /opt/python/lib/python3.13/site-packages (from dotenv->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: filelock>=3.10.0 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (2026.3.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface_hub->-r requirements.txt (line 2))
#   Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface_hub->-r requirements.txt (line 2))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: packaging>=20.9 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (4.67.3)
# Collecting typer (from huggingface_hub->-r requirements.txt (line 2))
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/python/lib/python3.13/site-packages (from huggingface_hub->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: anyio in /opt/python/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 2)) (4.13.0)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 2)) (2026.2.25)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 2))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/python/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/python/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: numpy>=1.17 in /opt/python/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 3)) (2.4.4)
# Requirement already satisfied: regex>=2025.10.22 in /opt/python/lib/python3.13/site-packages (from transformers->-r requirements.txt (line 3)) (2026.4.4)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers->-r requirements.txt (line 3))
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting safetensors>=0.4.3 (from transformers->-r requirements.txt (line 3))
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/python/lib/python3.13/site-packages (from datasets->-r requirements.txt (line 4)) (23.0.1)
# Collecting dill<0.4.2,>=0.3.0 (from datasets->-r requirements.txt (line 4))
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /opt/python/lib/python3.13/site-packages (from datasets->-r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/python/lib/python3.13/site-packages (from datasets->-r requirements.txt (line 4)) (2.33.1)
# Collecting xxhash (from datasets->-r requirements.txt (line 4))
#   Downloading xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets->-r requirements.txt (line 4))
#   Downloading multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->-r requirements.txt (line 2))
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/python/lib/python3.13/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (3.13.5)
# Requirement already satisfied: psutil in /opt/python/lib/python3.13/site-packages (from peft->-r requirements.txt (line 5)) (7.2.2)
# Requirement already satisfied: torch>=1.13.0 in /opt/python/lib/python3.13/site-packages (from peft->-r requirements.txt (line 5)) (2.7.1+cu118)
# Requirement already satisfied: setuptools in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /opt/python/lib/python3.13/site-packages (from torch>=1.13.0->peft->-r requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/python/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/python/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 9)) (9.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/python/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 9)) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->-r requirements.txt (line 9))
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->-r requirements.txt (line 9))
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/python/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.23.0)
# Requirement already satisfied: decorator>=5.1.0 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/python/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/python/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/python/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/python/lib/python3.13/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/python/lib/python3.13/site-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: executing>=1.2.0 in /opt/python/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/python/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: pure-eval in /opt/python/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/python/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/python/lib/python3.13/site-packages (from jinja2->torch>=1.13.0->peft->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas->datasets->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas->datasets->-r requirements.txt (line 4)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas->datasets->-r requirements.txt (line 4)) (2026.1)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /opt/python/lib/python3.13/site-packages (from typer->huggingface_hub->-r requirements.txt (line 2)) (8.3.2)
# Collecting shellingham>=1.3.0 (from typer->huggingface_hub->-r requirements.txt (line 2))
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface_hub->-r requirements.txt (line 2))
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/python/lib/python3.13/site-packages (from typer->huggingface_hub->-r requirements.txt (line 2)) (0.0.4)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface_hub->-r requirements.txt (line 2))
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->-r requirements.txt (line 2))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading huggingface_hub-1.9.1-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.4/637.4 kB 6.3 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 78.2 MB/s  0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 21.6 MB/s  0:00:00eta 0:00:01
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.6 MB/s  0:00:00
# Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 44.2 MB/s  0:00:00
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 47.9 MB/s  0:00:00
# Downloading trl-1.0.0-py3-none-any.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.8/630.8 kB 65.0 MB/s  0:00:00
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 95.3 MB/s  0:00:006m0:00:0100:01
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 68.3 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.8 MB/s  0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Installing collected packages: xxhash, widgetsnbextension, shellingham, safetensors, mdurl, jupyterlab_widgets, httpcore, hf-xet, fsspec, dotenv, dill, multiprocess, markdown-it-py, httpx, rich, ipywidgets, bitsandbytes, typer, huggingface_hub, tokenizers, datasets, accelerate, transformers, trl, peft
#   Attempting uninstall: fsspecm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/25 [httpcore]rs]
#     Found existing installation: fsspec 2026.3.0━━━━━━━━━━━━━━  6/25 [httpcore]
#     Uninstalling fsspec-2026.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/25 [httpcore]
#       Successfully uninstalled fsspec-2026.3.0━━━━━━━━━━━━━━━━━━━━  8/25 [fsspec]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25/25 [peft]2m24/25 [peft]formers]ub]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2026.3.0 requires fsspec==2026.3.0, but you have fsspec 2026.2.0 which is incompatible.
# Successfully installed accelerate-1.13.0 bitsandbytes-0.49.2 datasets-4.8.4 dill-0.4.1 dotenv-0.9.9 fsspec-2026.2.0 hf-xet-1.4.3 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-1.9.1 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 markdown-it-py-4.0.0 mdurl-0.1.2 multiprocess-0.70.19 peft-0.18.1 rich-14.3.3 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 transformers-5.5.0 trl-1.0.0 typer-0.24.1 widgetsnbextension-4.0.15 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print("Version de PyTorch :", torch.__version__)
print("Version de CUDA associée :", torch.version.cuda)
print("Le GPU est-il détecté ? :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("Nom du GPU :", torch.cuda.get_device_name(0))
# Out:
# Version de PyTorch : 2.6.0+cu124
# Version de CUDA associée : 12.4
# Le GPU est-il détecté ? : True
# Nom du GPU : NVIDIA A2

# %% [markdown]
# ## 1. Authentification HuggingFace

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login

load_dotenv()
login(token=os.getenv("HF_TOKEN"))
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## 2. Chargement du dataset et des métadonnées
#
# On charge les fichiers texte (professions de foi OCRisées) et le CSV de métadonnées,
# puis on les joint par l'identifiant de fichier (`id`).

# %%
from pathlib import Path
from datasets import load_dataset
import pandas as pd

# --- Fichiers texte à charger ---
PATTERNS = [
    "data/1981/legislatives/*PF*.txt",
    "data/1988/legislatives/*PF*.txt",
    "data/1993/legislatives/*PF*.txt",
]

# On résout les chemins dans le même ordre que load_dataset
# Note : load_dataset trie les fichiers par glob, on fait pareil avec sorted()
files = []
for p in PATTERNS:
    files.extend(sorted(Path().glob(p)))

dataset = load_dataset("text", data_files=PATTERNS, split="train", sample_by="document")
print(f"Dataset chargé : {len(dataset)} documents, {len(files)} fichiers résolus")

# --- Métadonnées ---
metadata = pd.read_csv("data/archelect_search.csv")
# Colonnes utiles uniquement
COLS_META = ["id", "titulaire-prenom", "titulaire-nom", "titulaire-profession",
             "titulaire-soutien", "contexte-tour", "date", "departement-nom"]
metadata_dict = metadata[COLS_META].set_index("id").to_dict("index")

print(f"Métadonnées : {len(metadata)} entrées")
# Out:
# Resolving data files:   0%|          | 0/12498 [00:00<?, ?it/s]
# Dataset chargé : 12498 documents, 12498 fichiers résolus
# Métadonnées : 12498 entrées

# %%
def add_metadata(example, idx):
    """Ajoute l'id (dérivé du nom de fichier) et les métadonnées associées."""
    path = files[idx]
    doc_id = path.stem
    example["id"] = doc_id
    example["annee"] = path.parts[-3]

    # Récupération des métadonnées (avec valeur par défaut si absent)
    meta = metadata_dict.get(doc_id, {})
    example["prenom"]     = meta.get("titulaire-prenom", "non mentionné")
    example["nom"]        = meta.get("titulaire-nom", "non mentionné")
    example["profession"] = meta.get("titulaire-profession", "non mentionné")
    example["soutien"]    = meta.get("titulaire-soutien", "non mentionné")
    example["tour"]       = meta.get("contexte-tour", "non mentionné")
    example["date"]       = meta.get("date", "non mentionné")
    example["departement"]= meta.get("departement-nom", "non mentionné")
    return example

dataset = dataset.map(add_metadata, with_indices=True)
print(dataset)
# Out:
# Dataset({
#     features: ['text', 'id', 'annee', 'prenom', 'nom', 'profession', 'soutien', 'tour', 'date', 'departement'],
#     num_rows: 12498
# })

# %% [markdown]
# ## 3. Construction des prompts
#
# Le prompt résume les métadonnées du candidat en langage naturel.
# Il sera utilisé comme message `user` dans le chat template.

# %%
def build_prompt(example):
    """Construit un prompt en langage naturel à partir des métadonnées."""
    parts = ["Rédige une profession de foi"]

    prenom, nom = example["prenom"], example["nom"]
    if prenom != "non mentionné" and nom != "non mentionné":
        parts.append(f"pour {prenom} {nom},")
    else:
        parts.append("pour le candidat,")

    profession = example["profession"]
    if profession != "non mentionné":
        metiers = [m.strip() for m in profession.split(";")]
        if len(metiers) > 1:
            parts.append(f"de professions {', '.join(metiers[:-1])} et {metiers[-1]},")
        else:
            parts.append(f"de profession {metiers[0]},")

    soutien = example["soutien"]
    if soutien != "non mentionné":
        partis = [p.strip() for p in soutien.split(";")]
        if len(partis) > 1:
            parts.append(f"soutenu par les partis {', '.join(partis[:-1])} et {partis[-1]}")
        else:
            parts.append(f"soutenu par le parti {partis[0]}")

    parts.append(f"au tour {example['tour']} des élections législatives de {example['date']}")
    parts.append(f"dans le département : {example['departement']}.")

    example["prompt"] = " ".join(parts)
    return example

dataset = dataset.map(build_prompt)

# Vérification rapide
print(dataset[0]["prompt"])
# Out:
# Rédige une profession de foi pour Micheline Antonucci, de profession assistance sociale, soutenu par le parti Parti socialiste unifié au tour 1 des élections législatives de 1981-06-14 dans le département : Ain.

# %% [markdown]
# ## 4. Nettoyage OCR
#
# Les textes sont issus d'OCR et contiennent des artefacts courants :
# mots coupés par un tiret en fin de ligne, filigranes CEVIPOF, mentions légales, etc.
#
# **Attention :** on ne colle PAS les tirets intra-ligne (ex. `Bourg-en-Bresse`)
# car cela détruirait les noms composés. On traite uniquement les coupures
# **de fin de ligne** (tiret suivi d'un saut de ligne).

# %%
import re

# Précompilation pour performances (appliqué sur 12k documents)
_RE_CUT_EOL    = re.compile(r'([A-Za-zÀ-ÿ]+)-\s*\n\s*([A-Za-zÀ-ÿ]+)')  # coupure fin de ligne uniquement
_RE_WATERMARK  = re.compile(r'Sciences Po / fonds CEVIPOF|[☐☒@¥]')
_RE_VU_CAND    = re.compile(r'vu\s*[,:\-]?\s*(le|la|les)\s+candidat[e]?[s]?\s*[:.]?', re.IGNORECASE)
_RE_DROP_LINE  = re.compile(
    r'^.*('
    r'imp\.?\s|imprimerie|imprimeurs|'
    r'r\.?c\.?\s|'
    r'\b\d{5}\b|'
    r'\b\d{1,2}([\s.\-]?\d{2}){3}\b'
    r').*$',
    re.IGNORECASE | re.MULTILINE
)
_RE_MULTILINE  = re.compile(r'\n{3,}')
_RE_MULTSPACE  = re.compile(r' {2,}')
_RE_ENUM       = re.compile(r'[:\n]\s*[•*>.o·]\s*', re.MULTILINE)

def clean_ocr(example):
    text = example["text"]
    text = _RE_CUT_EOL.sub(r'\1\2', text)     # recolle mots coupés en fin de ligne
    text = _RE_WATERMARK.sub("", text)          # filigranes
    text = _RE_VU_CAND.sub("", text)            # mention légale
    text = _RE_DROP_LINE.sub("", text)          # lignes techniques
    text = _RE_MULTILINE.sub('\n\n', text)      # sauts de ligne excessifs
    text = _RE_MULTSPACE.sub(' ', text)         # espaces multiples
    text = _RE_ENUM.sub("- ", text)             # normalisation listes
    example["text"] = text.strip()
    return example

dataset = dataset.map(clean_ocr, num_proc=4)
print("Nettoyage OCR terminé.")
# Out:
# Nettoyage OCR terminé.

# %% [markdown]
# ## 5. Formatage avec le chat template de Llama-3.2
#
# On construit les paires `(user, assistant)` et on applique le template du tokenizer.
# La colonne `formatted_text` sera celle passée au trainer.

# %%
from transformers import AutoTokenizer

MODEL_NAME = "meta-llama/Llama-3.2-1B-Instruct"

# On charge le tokenizer ici uniquement pour apply_chat_template
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"  # right pour l'entraînement (causal LM)

def apply_chat_template(example):
    """Formate le couple (prompt, texte) avec le template de conversation du modèle."""
    messages = [
        {"role": "user",      "content": example["prompt"]},
        {"role": "assistant", "content": example["text"]},
    ]
    example["formatted_text"] = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=False
    )
    return example

dataset = dataset.map(apply_chat_template)

# Vérification
print(dataset[0]["formatted_text"][:500])
print("...")
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 07 Apr 2026
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Rédige une profession de foi pour Micheline Antonucci, de profession assistance sociale, soutenu par le parti Parti socialiste unifié au tour 1 des élections législatives de 1981-06-14 dans le département : Ain.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# ELECTIONS LEGISLATIVES - 14 JUIN 1981 AIN 1e CIRCONSCRIP
# ...

# %%
# Split train / test (90% / 10%)
splits = dataset.train_test_split(test_size=0.1, seed=42)
train_dataset = splits["train"]
test_dataset  = splits["test"]

print(f"Train : {len(train_dataset)} | Test : {len(test_dataset)}")
# Out:
# Train : 11248 | Test : 1250

# %% [markdown]
# ## 6. Chargement du modèle (QLoRA 4-bit)
#
# **Points critiques pour la Tesla T4 :**
# - La T4 **ne supporte pas `bf16`** (bfloat16). Il faut utiliser `fp16` (float16).
# - On spécifie `torch_dtype=torch.float16` dès le chargement pour que Llama-3.2
#   charge directement ses couches non-quantifiées (lm_head, embed_tokens) en float16.
# - Pas besoin de boucle de cast manuel après coup.

# %%
import torch
from transformers import AutoModelForCausalLM

MODEL_NAME = "meta-llama/Llama-3.2-1B-Instruct"

# Chargement en float16 classique (compatible T4 et A2)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    dtype=torch.float16,
)
model.config.use_cache = False
model.config.pretraining_tp = 1

print("Modèle de base chargé en float16 (sans quantification).")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/146 [00:00<?, ?it/s]
# Modèle de base chargé en float16 (sans quantification).

# %%
# --- Configuration LoRA ---
# r=16 suffit largement pour ce type de tâche de génération stylistique.
# r=64 (comme dans le livre) est adapté pour des tâches complexes mais ralentit l'entraînement.
# Règle : lora_alpha = 2 * r
from peft import LoraConfig, get_peft_model

peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                    "gate_proj", "up_proj", "down_proj"],
)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# trainable params: 11,272,192 || all params: 1,247,086,592 || trainable%: 0.9039

# %% [markdown]
# ## 7. Entraînement
#
# **Paramètres importants pour la T4 :**
# - `fp16=True`, `bf16=False` — indispensable sur T4
# - `optim="paged_adamw_32bit"` — optimiseur paginé du papier QLoRA, réduit la VRAM
# - `max_seq_length=1024` — les professions de foi font souvent ~400-800 tokens,
#   1024 est un bon compromis vitesse/couverture (2048 doublerait l'usage VRAM)
# - `packing=True` — emballe plusieurs courtes séquences dans un même batch : accélère notablement l'entraînement

# %%
from trl import SFTTrainer, SFTConfig

# 1. Nettoyage strict des colonnes du dataset
colonnes_a_supprimer = [col for col in train_dataset.column_names if col != "formatted_text"]
train_dataset_clean = train_dataset.remove_columns(colonnes_a_supprimer)

# 2. Paramètres d'entraînement unifiés
training_args = SFTConfig(
    output_dir="./results",
    num_train_epochs=1,
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    
    # Précision fixe pour garantir le fonctionnement sur T4 et A2
    fp16=True,
    bf16=False,
    
    # Optimiseur standard (remplace paged_adamw qui est lié à QLoRA)
    optim="adamw_torch",
    
    dataset_text_field="formatted_text",
    max_length=1024,
    packing=False,
    
    logging_steps=25,
    save_steps=200,
    report_to="none",
)

# 3. Lancement du Trainer
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_clean,
    processing_class=tokenizer,
    args=training_args,
)

trainer.train()

# 4. Sauvegarde des poids
trainer.model.save_pretrained("Llama-1B-Archelec-LoRA-Standard")
tokenizer.save_pretrained("Llama-1B-Archelec-LoRA-Standard")
print("Entraînement terminé et poids sauvegardés.")
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 128009, 'pad_token_id': 128009}.
#     <div>
#
#       <progress value='130' max='1406' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 130/1406 17:04 < 2:50:17, 0.12 it/s, Epoch 0.09/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>2.365699</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.104792</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.955023</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.829026</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.824337</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 41
#      37     processing_class=tokenizer,
#      38     args=training_args,
#      39 )
#      40
# ---> 41 trainer.train()
#      42
#      43 # 4. Sauvegarde des poids
#      44 trainer.model.save_pretrained("Llama-1B-Archelec-LoRA-Standard")
#
# File /opt/python/lib/python3.13/site-packages/transformers/trainer.py:1424, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1422 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1423 with ctx:
# -> 1424     return inner_training_loop(
#    1425         args=args,
#    1426         resume_from_checkpoint=resume_from_checkpoint,
#    1427         trial=trial,
#    1428         ignore_keys_for_eval=ignore_keys_for_eval,
#    1429     )
#
# File /opt/python/lib/python3.13/site-packages/transformers/trainer.py:1506, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1504 for epoch in range(epochs_trained, num_train_epochs):
#    1505     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1506     self._run_epoch(
#    1507         model=model,
#    1508         epoch=epoch,
#    1509         train_dataloader=train_dataloader,
#    1510         steps_in_epoch=steps_in_epoch,
#    1511         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1512         trial=trial,
#    1513         ignore_keys_for_eval=ignore_keys_for_eval,
#    1514         start_time=start_time,
#    1515         resume_from_checkpoint=resume_from_checkpoint,
#    1516         epochs_trained=epochs_trained,
#    1517         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1518     )
#    1519     if self.control.should_training_stop:
#    1520         break
#
# File /opt/python/lib/python3.13/site-packages/transformers/trainer.py:1734, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1732     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1733 with sync_context():
# -> 1734     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1736 if (
#    1737     self.args.logging_nan_inf_filter
#    1738     and not is_torch_xla_available()
#    1739     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1740 ):
#    1741     # if loss is nan or inf simply add the average of previous logged losses
#    1742     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /opt/python/lib/python3.13/site-packages/trl/trainer/sft_trainer.py:1379, in SFTTrainer.training_step(self, *args, **kwargs)
#    1377 def training_step(self, *args, **kwargs):
#    1378     with self.maybe_activation_offload_context:
# -> 1379         return super().training_step(*args, **kwargs)
#
# File /opt/python/lib/python3.13/site-packages/transformers/trainer.py:1934, in Trainer.training_step(***failed resolving arguments***)
#    1931 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    1932     kwargs["scale_wrt_gas"] = False
# -> 1934 self.accelerator.backward(loss, **kwargs)
#    1936 return loss.detach()
#
# File /opt/python/lib/python3.13/site-packages/accelerate/accelerator.py:2834, in Accelerator.backward(self, loss, **kwargs)
#    2832     return
#    2833 elif self.scaler is not None:
# -> 2834     self.scaler.scale(loss).backward(**kwargs)
#    2835 elif learning_rate is not None and self.has_lomo_optimizer:
#    2836     self.lomo_backward(loss, learning_rate)
#
# File /opt/python/lib/python3.13/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /opt/python/lib/python3.13/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/python/lib/python3.13/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from trl import SFTTrainer, SFTConfig

# Nettoyage des colonnes (toujours nécessaire pour trl)
colonnes_a_supprimer = [col for col in train_dataset.column_names if col != "formatted_text"]
train_dataset_clean = train_dataset.remove_columns(colonnes_a_supprimer)

training_args = SFTConfig(
    output_dir="./results",
    num_train_epochs=1,
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    
    # --- Changements pour la puce A2 ---
    fp16=False,     
    bf16=True,      # Supporté nativement par l'A2
    packing=True,   # Réactivé grâce à Flash Attention 2
    # -----------------------------------
    
    optim="paged_adamw_32bit",
    dataset_text_field="formatted_text",
    max_length=1024,
    logging_steps=25,
    save_steps=200,
    report_to="none",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_clean,
    processing_class=tokenizer,
    args=training_args,
)

trainer.train()

trainer.model.save_pretrained("Llama-1B-Archelec-LoRA")
tokenizer.save_pretrained("Llama-1B-Archelec-LoRA")
print("Entraînement terminé et poids sauvegardés.")

# %% [markdown]
# ## 8. Inférence & comparaison base vs fine-tuné
#
# On charge les poids LoRA sur le modèle de base et on génère une profession de foi test.
# On compare avec le modèle de base (sans LoRA) pour mesurer l'effet du fine-tuning.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
import torch

ADAPTER_PATH = "Llama-1B-Archelec-LoRA"

# --- Tokenizer (padding LEFT pour la génération) ---
tokenizer_inf = AutoTokenizer.from_pretrained(ADAPTER_PATH)
tokenizer_inf.padding_side = "left"

# --- Modèle de base en 4-bit ---
bnb_config_inf = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)
base_model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    device_map="auto",
    quantization_config=bnb_config_inf,
    torch_dtype=torch.float16,
)

# --- Chargement de l'adaptateur LoRA ---
model_ft = PeftModel.from_pretrained(base_model, ADAPTER_PATH)

print("Modèle fine-tuné chargé.")

# %%
def generate(model, tokenizer, prompt_text, max_new_tokens=400):
    """Génère une réponse à partir d'un prompt utilisateur."""
    messages = [{"role": "user", "content": prompt_text}]
    formatted = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(formatted, return_tensors="pt").to("cuda")
    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.7,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
        )
    decoded = tokenizer.decode(output[0], skip_special_tokens=True)
    # Isole la réponse de l'assistant
    return decoded.split("assistant\n")[-1].strip() if "assistant\n" in decoded else decoded


# --- Prompt de test ---
TEST_PROMPT = (
    "Rédige une profession de foi pour Jean Dupont, de profession professeur, "
    "soutenu par le parti Parti communiste français "
    "au tour 1 des élections législatives de 1981-06-14 "
    "dans le département : Paris."
)

print("=" * 60)
print("MODÈLE FINE-TUNÉ (Archelec-LoRA)")
print("=" * 60)
print(generate(model_ft, tokenizer_inf, TEST_PROMPT))

print("\n" + "=" * 60)
print("MODÈLE DE BASE (Llama-3.2-1B-Instruct sans fine-tuning)")
print("=" * 60)
with model_ft.disable_adapter():
    print(generate(model_ft, tokenizer_inf, TEST_PROMPT))
